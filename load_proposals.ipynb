# %%
import pickle

# %%
with open('proposal/MCG-coco_2014_train-boxes.pkl', 'rb') as f:
    mcg_proposals = pickle.load(f, encoding="latin1")

# %%
type(proposals)
# Out:
# dict

# %%
proposals.keys()
# Out:
# dict_keys(['boxes', 'indexes', 'scores'])

# %%
len(proposals['scores'][0])
# Out:
# 2357

# %%
len(proposals['boxes'][0])
# Out:
# 2357

# %%
proposals['indexes'][0]
# Out:
# 9

# %%
proposals['boxes']
# Out:
# [array([[447., 197., 639., 479.],
#         [  0., 111., 228., 342.],
#         [  0., 191., 565., 479.],
#         ...,
#         [460., 313., 473., 323.],
#         [247., 210., 296., 237.],
#         [330.,  39., 350.,  57.]], dtype=float32),
#  array([[383.,  98., 549., 359.],
#         [534., 270., 599., 348.],
#         [383., 194., 452., 359.],
#         ...,
#         [319., 382., 325., 386.],
#         [312., 380., 318., 385.],
#         [479., 226., 494., 239.]], dtype=float32),
#  array([[207.,  37., 443., 206.],
#         [593., 139., 639., 189.],
#         [  0., 202., 178., 342.],
#         ...,
#         [341.,  84., 349.,  99.],
#         [351., 134., 358., 140.],
#         [611., 183., 616., 188.]], dtype=float32),
#  array([[  0., 198., 170., 367.],
#         [253.,  98., 428., 418.],
#         [164., 156., 293., 382.],
#         ...,
#         [376., 208., 388., 227.],
#         [254., 200., 260., 219.],
#         [356., 206., 367., 240.]], dtype=float32),
# ...

# %%
len(mcg_proposals['scores'][0])
# Out:
# 2357

# %%
proposals['indexes']
# Out:
# [9,
#  25,
#  30,
#  34,
#  36,
#  49,
#  61,
#  64,
#  71,
#  72,
#  77,
#  78,
#  81,
#  86,
#  89,
#  92,
#  94,
#  109,
#  110,
#  113,
#  127,
#  138,
#  142,
#  144,
#  149,
#  151,
#  154,
#  165,
#  194,
#  201,
#  247,
#  250,
#  260,
#  263,
#  307,
#  308,
#  309,
#  312,
#  315,
#  321,
#  322,
#  326,
#  332,
#  349,
#  368,
#  370,
#  382,
#  384,
#  389,
#  394,
#  404,
#  419,
#  431,
#  436,
#  438,
#  443,
#  446,
#  450,
#  471,
#  490,
#  491,
#  508,
#  510,
#  514,
#  529,
#  531,
#  532,
#  540,
#  542,
#  560,
#  562,
#  572,
#  575,
#  581,
#  584,
#  595,
#  597,
#  605,
#  612,
#  620,
#  625,
#  629,
#  634,
#  643,
#  650,
#  656,
#  659,
#  670,
#  671,
#  673,
#  681,
#  684,
#  690,
#  706,
#  714,
#  716,
#  722,
#  723,
#  731,
#  735,
#  753,
#  754,
#  762,
#  781,
#  790,
#  795,
#  797,
#  801,
#  813,
#  821,
#  825,
#  828,
#  839,
#  853,
#  882,
#  897,
#  901,
#  902,
#  908,
#  909,
#  913,
#  925,
#  927,
#  934,
#  941,
#  943,
#  955,
# ...

# %%
with open('proposal/EdgeBoxes-dishwasher_train_im_data_augmented_score.pkl', 'rb') as f:
    proposals = pickle.load(f, encoding="latin1")

# %%
proposals.keys()
# Out:
# dict_keys(['boxes', 'scores', 'indexes'])

# %%
proposals['scores']
# Out:
# [array([[0.68915045],
#         [0.6663215 ],
#         [0.64487433],
#         [0.6443283 ],
#         [0.6318421 ],
#         [0.6257984 ],
#         [0.6104329 ],
#         [0.59485847],
#         [0.5909081 ],
#         [0.5893613 ],
#         [0.58731747],
#         [0.5868089 ],
#         [0.58583546],
#         [0.5842089 ],
#         [0.58076763],
#         [0.5795409 ],
#         [0.57795346],
#         [0.5771402 ],
#         [0.57712966],
#         [0.5766192 ],
#         [0.5761088 ],
#         [0.57408386],
#         [0.5703389 ],
#         [0.5697425 ],
#         [0.56812763],
#         [0.5680163 ],
#         [0.5660644 ],
#         [0.56539536],
#         [0.56458277],
#         [0.5635114 ],
#         [0.56259245],
#         [0.56120485],
#         [0.56064945],
#         [0.5584276 ],
#         [0.5580688 ],
#         [0.55702007],
#         [0.5554847 ],
#         [0.55462164],
#         [0.5541854 ],
#         [0.55411404],
#         [0.55301195],
# ...
